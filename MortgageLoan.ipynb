# %%
import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Set the value of the home you are looking to buy
home_value = 350000

# What percentage are you paying up-front?
down_payment_percent = 0.25

# Calculate the dollar value of the down payment
down_payment = home_value * down_payment_percent
print("Initial Down Payment: " + str(down_payment))

# Calculate the value of the mortgage loan required after the down payment
mortgage_loan = home_value - down_payment
print("Mortgage Loan: " + str(mortgage_loan))
# Out:
# Initial Down Payment: 87500.0
# Mortgage Loan: 262500.0

# %%
mortgage_rate = 0.025

# Derive the equivalent monthly mortgage rate from the annual rate
mortgage_rate_periodic = (1 + mortgage_rate) ** (1/12) - 1

# How many monthly payment periods will there be over 20 years?
mortgage_payment_periods = 20 * 12

# Calculate the monthly mortgage payment (multiply by -1 to keep it positive)
periodic_mortgage_payment = -1*npf.pmt(mortgage_rate_periodic, mortgage_payment_periods, mortgage_loan)
print("Monthly Mortgage Payment: " + str(round(periodic_mortgage_payment, 2)))
# Out:
# Monthly Mortgage Payment: 1387.39

# %%
# Calculate the amount of the first loan payment that will go towards interest
initial_interest_payment = mortgage_loan * mortgage_rate_periodic
print("Initial Interest Payment: " + str(round(initial_interest_payment, 2)))

# Calculate the amount of the first loan payment that will go towards principal
initial_principal_payment = periodic_mortgage_payment - initial_interest_payment
print("Initial Principal Payment: " + str(round(initial_principal_payment, 2)))
# Out:
# Initial Interest Payment: 540.71
# Initial Principal Payment: 846.69

# %%
principal_remaining = np.empty([mortgage_payment_periods])

# Loop through each mortgage payment period
for i in range(0, mortgage_payment_periods):
    
    # Handle the case for the first iteration
    if i == 0:
        previous_principal_remaining = mortgage_loan
    else:
        previous_principal_remaining = principal_remaining[i - 1]
        
    # Calculate the interest and principal payments
    interest_payment = round(previous_principal_remaining*mortgage_rate_periodic, 2)
    principal_payment = round(periodic_mortgage_payment-interest_payment, 2)
    
    # Catch the case where all principal is paid off in the final period
    if previous_principal_remaining - principal_payment < 0:
        principal_payment = previous_principal_remaining
        
    # Collect the principal remaining values in an array
    principal_remaining[i] = previous_principal_remaining - principal_payment
    
    print("Interest: $" + str(interest_payment) + " Principal: $" + str(round(principal_payment, 2))  + " Remaining: $" + str(round(principal_remaining[i], 2)))
# Out:
# Interest: $540.71 Principal: $846.68 Remaining: $261653.32
# Interest: $538.96 Principal: $848.43 Remaining: $260804.89
# Interest: $537.22 Principal: $850.17 Remaining: $259954.72
# Interest: $535.46 Principal: $851.93 Remaining: $259102.79
# Interest: $533.71 Principal: $853.68 Remaining: $258249.11
# Interest: $531.95 Principal: $855.44 Remaining: $257393.67
# Interest: $530.19 Principal: $857.2 Remaining: $256536.47
# Interest: $528.42 Principal: $858.97 Remaining: $255677.5
# Interest: $526.65 Principal: $860.74 Remaining: $254816.76
# Interest: $524.88 Principal: $862.51 Remaining: $253954.25
# Interest: $523.1 Principal: $864.29 Remaining: $253089.96
# Interest: $521.32 Principal: $866.07 Remaining: $252223.89
# Interest: $519.54 Principal: $867.85 Remaining: $251356.04
# Interest: $517.75 Principal: $869.64 Remaining: $250486.4
# Interest: $515.96 Principal: $871.43 Remaining: $249614.97
# Interest: $514.17 Principal: $873.22 Remaining: $248741.75
# Interest: $512.37 Principal: $875.02 Remaining: $247866.73
# Interest: $510.56 Principal: $876.83 Remaining: $246989.9
# Interest: $508.76 Principal: $878.63 Remaining: $246111.27
# Interest: $506.95 Principal: $880.44 Remaining: $245230.83
# Interest: $505.14 Principal: $882.25 Remaining: $244348.58
# Interest: $503.32 Principal: $884.07 Remaining: $243464.51
# Interest: $501.5 Principal: $885.89 Remaining: $242578.62
# Interest: $499.67 Principal: $887.72 Remaining: $241690.9
# Interest: $497.84 Principal: $889.55 Remaining: $240801.35
# Interest: $496.01 Principal: $891.38 Remaining: $239909.97
# Interest: $494.18 Principal: $893.21 Remaining: $239016.76
# Interest: $492.34 Principal: $895.05 Remaining: $238121.71
# Interest: $490.49 Principal: $896.9 Remaining: $237224.81
# Interest: $488.64 Principal: $898.75 Remaining: $236326.06
# Interest: $486.79 Principal: $900.6 Remaining: $235425.46
# Interest: $484.94 Principal: $902.45 Remaining: $234523.01
# Interest: $483.08 Principal: $904.31 Remaining: $233618.7
# Interest: $481.22 Principal: $906.17 Remaining: $232712.53
# Interest: $479.35 Principal: $908.04 Remaining: $231804.49
# Interest: $477.48 Principal: $909.91 Remaining: $230894.58
# Interest: $475.61 Principal: $911.78 Remaining: $229982.8
# Interest: $473.73 Principal: $913.66 Remaining: $229069.14
# Interest: $471.84 Principal: $915.55 Remaining: $228153.59
# Interest: $469.96 Principal: $917.43 Remaining: $227236.16
# Interest: $468.07 Principal: $919.32 Remaining: $226316.84
# Interest: $466.18 Principal: $921.21 Remaining: $225395.63
# Interest: $464.28 Principal: $923.11 Remaining: $224472.52
# Interest: $462.38 Principal: $925.01 Remaining: $223547.51
# Interest: $460.47 Principal: $926.92 Remaining: $222620.59
# Interest: $458.56 Principal: $928.83 Remaining: $221691.76
# Interest: $456.65 Principal: $930.74 Remaining: $220761.02
# Interest: $454.73 Principal: $932.66 Remaining: $219828.36
# Interest: $452.81 Principal: $934.58 Remaining: $218893.78
# Interest: $450.89 Principal: $936.5 Remaining: $217957.28
# Interest: $448.96 Principal: $938.43 Remaining: $217018.85
# Interest: $447.02 Principal: $940.37 Remaining: $216078.48
# Interest: $445.09 Principal: $942.3 Remaining: $215136.18
# Interest: $443.15 Principal: $944.24 Remaining: $214191.94
# Interest: $441.2 Principal: $946.19 Remaining: $213245.75
# Interest: $439.25 Principal: $948.14 Remaining: $212297.61
# Interest: $437.3 Principal: $950.09 Remaining: $211347.52
# Interest: $435.34 Principal: $952.05 Remaining: $210395.47
# Interest: $433.38 Principal: $954.01 Remaining: $209441.46
# Interest: $431.42 Principal: $955.97 Remaining: $208485.49
# Interest: $429.45 Principal: $957.94 Remaining: $207527.55
# Interest: $427.47 Principal: $959.92 Remaining: $206567.63
# Interest: $425.5 Principal: $961.89 Remaining: $205605.74
# Interest: $423.51 Principal: $963.88 Remaining: $204641.86
# Interest: $421.53 Principal: $965.86 Remaining: $203676.0
# Interest: $419.54 Principal: $967.85 Remaining: $202708.15
# Interest: $417.55 Principal: $969.84 Remaining: $201738.31
# Interest: $415.55 Principal: $971.84 Remaining: $200766.47
# Interest: $413.55 Principal: $973.84 Remaining: $199792.63
# Interest: $411.54 Principal: $975.85 Remaining: $198816.78
# Interest: $409.53 Principal: $977.86 Remaining: $197838.92
# Interest: $407.52 Principal: $979.87 Remaining: $196859.05
# Interest: $405.5 Principal: $981.89 Remaining: $195877.16
# Interest: $403.47 Principal: $983.92 Remaining: $194893.24
# Interest: $401.45 Principal: $985.94 Remaining: $193907.3
# Interest: $399.42 Principal: $987.97 Remaining: $192919.33
# Interest: $397.38 Principal: $990.01 Remaining: $191929.32
# Interest: $395.34 Principal: $992.05 Remaining: $190937.27
# Interest: $393.3 Principal: $994.09 Remaining: $189943.18
# Interest: $391.25 Principal: $996.14 Remaining: $188947.04
# Interest: $389.2 Principal: $998.19 Remaining: $187948.85
# Interest: $387.14 Principal: $1000.25 Remaining: $186948.6
# Interest: $385.08 Principal: $1002.31 Remaining: $185946.29
# Interest: $383.02 Principal: $1004.37 Remaining: $184941.92
# Interest: $380.95 Principal: $1006.44 Remaining: $183935.48
# Interest: $378.88 Principal: $1008.51 Remaining: $182926.97
# Interest: $376.8 Principal: $1010.59 Remaining: $181916.38
# Interest: $374.72 Principal: $1012.67 Remaining: $180903.71
# Interest: $372.63 Principal: $1014.76 Remaining: $179888.95
# Interest: $370.54 Principal: $1016.85 Remaining: $178872.1
# Interest: $368.45 Principal: $1018.94 Remaining: $177853.16
# Interest: $366.35 Principal: $1021.04 Remaining: $176832.12
# Interest: $364.25 Principal: $1023.14 Remaining: $175808.98
# Interest: $362.14 Principal: $1025.25 Remaining: $174783.73
# Interest: $360.03 Principal: $1027.36 Remaining: $173756.37
# Interest: $357.91 Principal: $1029.48 Remaining: $172726.89
# Interest: $355.79 Principal: $1031.6 Remaining: $171695.29
# Interest: $353.66 Principal: $1033.73 Remaining: $170661.56
# Interest: $351.53 Principal: $1035.86 Remaining: $169625.7
# Interest: $349.4 Principal: $1037.99 Remaining: $168587.71
# Interest: $347.26 Principal: $1040.13 Remaining: $167547.58
# Interest: $345.12 Principal: $1042.27 Remaining: $166505.31
# Interest: $342.97 Principal: $1044.42 Remaining: $165460.89
# Interest: $340.82 Principal: $1046.57 Remaining: $164414.32
# Interest: $338.67 Principal: $1048.72 Remaining: $163365.6
# Interest: $336.51 Principal: $1050.88 Remaining: $162314.72
# Interest: $334.34 Principal: $1053.05 Remaining: $161261.67
# Interest: $332.17 Principal: $1055.22 Remaining: $160206.45
# Interest: $330.0 Principal: $1057.39 Remaining: $159149.06
# Interest: $327.82 Principal: $1059.57 Remaining: $158089.49
# Interest: $325.64 Principal: $1061.75 Remaining: $157027.74
# Interest: $323.45 Principal: $1063.94 Remaining: $155963.8
# Interest: $321.26 Principal: $1066.13 Remaining: $154897.67
# Interest: $319.06 Principal: $1068.33 Remaining: $153829.34
# Interest: $316.86 Principal: $1070.53 Remaining: $152758.81
# Interest: $314.66 Principal: $1072.73 Remaining: $151686.08
# Interest: $312.45 Principal: $1074.94 Remaining: $150611.14
# Interest: $310.23 Principal: $1077.16 Remaining: $149533.98
# Interest: $308.02 Principal: $1079.37 Remaining: $148454.61
# Interest: $305.79 Principal: $1081.6 Remaining: $147373.01
# Interest: $303.56 Principal: $1083.83 Remaining: $146289.18
# Interest: $301.33 Principal: $1086.06 Remaining: $145203.12
# Interest: $299.09 Principal: $1088.3 Remaining: $144114.82
# Interest: $296.85 Principal: $1090.54 Remaining: $143024.28
# Interest: $294.61 Principal: $1092.78 Remaining: $141931.5
# Interest: $292.36 Principal: $1095.03 Remaining: $140836.47
# Interest: $290.1 Principal: $1097.29 Remaining: $139739.18
# Interest: $287.84 Principal: $1099.55 Remaining: $138639.63
# Interest: $285.57 Principal: $1101.82 Remaining: $137537.81
# Interest: $283.31 Principal: $1104.08 Remaining: $136433.73
# Interest: $281.03 Principal: $1106.36 Remaining: $135327.37
# Interest: $278.75 Principal: $1108.64 Remaining: $134218.73
# Interest: $276.47 Principal: $1110.92 Remaining: $133107.81
# Interest: $274.18 Principal: $1113.21 Remaining: $131994.6
# Interest: $271.89 Principal: $1115.5 Remaining: $130879.1
# Interest: $269.59 Principal: $1117.8 Remaining: $129761.3
# Interest: $267.29 Principal: $1120.1 Remaining: $128641.2
# Interest: $264.98 Principal: $1122.41 Remaining: $127518.79
# Interest: $262.67 Principal: $1124.72 Remaining: $126394.07
# Interest: $260.35 Principal: $1127.04 Remaining: $125267.03
# Interest: $258.03 Principal: $1129.36 Remaining: $124137.67
# Interest: $255.7 Principal: $1131.69 Remaining: $123005.98
# Interest: $253.37 Principal: $1134.02 Remaining: $121871.96
# Interest: $251.04 Principal: $1136.35 Remaining: $120735.61
# Interest: $248.7 Principal: $1138.69 Remaining: $119596.92
# Interest: $246.35 Principal: $1141.04 Remaining: $118455.88
# Interest: $244.0 Principal: $1143.39 Remaining: $117312.49
# Interest: $241.64 Principal: $1145.75 Remaining: $116166.74
# Interest: $239.28 Principal: $1148.11 Remaining: $115018.63
# Interest: $236.92 Principal: $1150.47 Remaining: $113868.16
# Interest: $234.55 Principal: $1152.84 Remaining: $112715.32
# Interest: $232.18 Principal: $1155.21 Remaining: $111560.11
# Interest: $229.8 Principal: $1157.59 Remaining: $110402.52
# Interest: $227.41 Principal: $1159.98 Remaining: $109242.54
# Interest: $225.02 Principal: $1162.37 Remaining: $108080.17
# Interest: $222.63 Principal: $1164.76 Remaining: $106915.41
# Interest: $220.23 Principal: $1167.16 Remaining: $105748.25
# Interest: $217.82 Principal: $1169.57 Remaining: $104578.68
# Interest: $215.41 Principal: $1171.98 Remaining: $103406.7
# Interest: $213.0 Principal: $1174.39 Remaining: $102232.31
# Interest: $210.58 Principal: $1176.81 Remaining: $101055.5
# Interest: $208.16 Principal: $1179.23 Remaining: $99876.27
# Interest: $205.73 Principal: $1181.66 Remaining: $98694.61
# Interest: $203.29 Principal: $1184.1 Remaining: $97510.51
# Interest: $200.86 Principal: $1186.53 Remaining: $96323.98
# Interest: $198.41 Principal: $1188.98 Remaining: $95135.0
# Interest: $195.96 Principal: $1191.43 Remaining: $93943.57
# Interest: $193.51 Principal: $1193.88 Remaining: $92749.69
# Interest: $191.05 Principal: $1196.34 Remaining: $91553.35
# Interest: $188.58 Principal: $1198.81 Remaining: $90354.54
# Interest: $186.12 Principal: $1201.27 Remaining: $89153.27
# Interest: $183.64 Principal: $1203.75 Remaining: $87949.52
# Interest: $181.16 Principal: $1206.23 Remaining: $86743.29
# Interest: $178.68 Principal: $1208.71 Remaining: $85534.58
# Interest: $176.19 Principal: $1211.2 Remaining: $84323.38
# Interest: $173.69 Principal: $1213.7 Remaining: $83109.68
# Interest: $171.19 Principal: $1216.2 Remaining: $81893.48
# Interest: $168.69 Principal: $1218.7 Remaining: $80674.78
# Interest: $166.18 Principal: $1221.21 Remaining: $79453.57
# Interest: $163.66 Principal: $1223.73 Remaining: $78229.84
# Interest: $161.14 Principal: $1226.25 Remaining: $77003.59
# Interest: $158.61 Principal: $1228.78 Remaining: $75774.81
# Interest: $156.08 Principal: $1231.31 Remaining: $74543.5
# Interest: $153.55 Principal: $1233.84 Remaining: $73309.66
# Interest: $151.01 Principal: $1236.38 Remaining: $72073.28
# Interest: $148.46 Principal: $1238.93 Remaining: $70834.35
# Interest: $145.91 Principal: $1241.48 Remaining: $69592.87
# Interest: $143.35 Principal: $1244.04 Remaining: $68348.83
# Interest: $140.79 Principal: $1246.6 Remaining: $67102.23
# Interest: $138.22 Principal: $1249.17 Remaining: $65853.06
# Interest: $135.65 Principal: $1251.74 Remaining: $64601.32
# Interest: $133.07 Principal: $1254.32 Remaining: $63347.0
# Interest: $130.48 Principal: $1256.91 Remaining: $62090.09
# Interest: $127.9 Principal: $1259.49 Remaining: $60830.6
# Interest: $125.3 Principal: $1262.09 Remaining: $59568.51
# Interest: $122.7 Principal: $1264.69 Remaining: $58303.82
# Interest: $120.1 Principal: $1267.29 Remaining: $57036.53
# Interest: $117.49 Principal: $1269.9 Remaining: $55766.63
# Interest: $114.87 Principal: $1272.52 Remaining: $54494.11
# Interest: $112.25 Principal: $1275.14 Remaining: $53218.97
# Interest: $109.62 Principal: $1277.77 Remaining: $51941.2
# Interest: $106.99 Principal: $1280.4 Remaining: $50660.8
# Interest: $104.35 Principal: $1283.04 Remaining: $49377.76
# Interest: $101.71 Principal: $1285.68 Remaining: $48092.08
# Interest: $99.06 Principal: $1288.33 Remaining: $46803.75
# Interest: $96.41 Principal: $1290.98 Remaining: $45512.77
# Interest: $93.75 Principal: $1293.64 Remaining: $44219.13
# Interest: $91.08 Principal: $1296.31 Remaining: $42922.82
# Interest: $88.41 Principal: $1298.98 Remaining: $41623.84
# Interest: $85.74 Principal: $1301.65 Remaining: $40322.19
# Interest: $83.06 Principal: $1304.33 Remaining: $39017.86
# Interest: $80.37 Principal: $1307.02 Remaining: $37710.84
# Interest: $77.68 Principal: $1309.71 Remaining: $36401.13
# Interest: $74.98 Principal: $1312.41 Remaining: $35088.72
# Interest: $72.28 Principal: $1315.11 Remaining: $33773.61
# Interest: $69.57 Principal: $1317.82 Remaining: $32455.79
# Interest: $66.85 Principal: $1320.54 Remaining: $31135.25
# Interest: $64.13 Principal: $1323.26 Remaining: $29811.99
# Interest: $61.41 Principal: $1325.98 Remaining: $28486.01
# Interest: $58.68 Principal: $1328.71 Remaining: $27157.3
# Interest: $55.94 Principal: $1331.45 Remaining: $25825.85
# Interest: $53.2 Principal: $1334.19 Remaining: $24491.66
# Interest: $50.45 Principal: $1336.94 Remaining: $23154.72
# Interest: $47.69 Principal: $1339.7 Remaining: $21815.02
# Interest: $44.94 Principal: $1342.45 Remaining: $20472.57
# Interest: $42.17 Principal: $1345.22 Remaining: $19127.35
# Interest: $39.4 Principal: $1347.99 Remaining: $17779.36
# Interest: $36.62 Principal: $1350.77 Remaining: $16428.59
# Interest: $33.84 Principal: $1353.55 Remaining: $15075.04
# Interest: $31.05 Principal: $1356.34 Remaining: $13718.7
# Interest: $28.26 Principal: $1359.13 Remaining: $12359.57
# Interest: $25.46 Principal: $1361.93 Remaining: $10997.64
# Interest: $22.65 Principal: $1364.74 Remaining: $9632.9
# Interest: $19.84 Principal: $1367.55 Remaining: $8265.35
# Interest: $17.03 Principal: $1370.36 Remaining: $6894.99
# Interest: $14.2 Principal: $1373.19 Remaining: $5521.8
# Interest: $11.37 Principal: $1376.02 Remaining: $4145.78
# Interest: $8.54 Principal: $1378.85 Remaining: $2766.93
# Interest: $5.7 Principal: $1381.69 Remaining: $1385.24
# Interest: $2.85 Principal: $1384.54 Remaining: $0.7

# %%
interest_paid = np.empty([mortgage_payment_periods])
principal_paid = np.empty([mortgage_payment_periods])

# Loop through each mortgage payment period
for i in range(0, mortgage_payment_periods):
    
    # Handle the case for the first iteration
    if i == 0:
        previous_principal_remaining = mortgage_loan
    else:
        previous_principal_remaining = principal_remaining[i-1]
        
    # Calculate the interest based on the previous principal
    interest_payment = round(previous_principal_remaining*mortgage_rate_periodic, 2)
    principal_payment = round(periodic_mortgage_payment - interest_payment, 2)
    
    # Catch the case where all principal is paid off in the final period
    if previous_principal_remaining - principal_payment < 0:
        principal_payment = previous_principal_remaining
        
    # Collect the historical values
    interest_paid[i] = interest_payment
    principal_paid[i] = principal_payment
    principal_remaining[i] = previous_principal_remaining - principal_payment
    
# Plot the interest vs principal
plt.plot(interest_paid, color="red", label="Interest")
plt.plot(principal_paid, color="blue", label="Principal")
plt.legend()
plt.show()

# %%
# Calculate the cumulative home equity (principal) over time
cumulative_home_equity = np.cumsum(principal_paid)

# Calculate the cumulative interest paid over time
cumulative_interest_paid = np.cumsum(interest_paid)

# Calculate your percentage home equity over time
cumulative_percent_owned = (down_payment/home_value) + (cumulative_home_equity/home_value)
print(cumulative_percent_owned)

# Plot the cumulative interest paid vs equity accumulated
plt.plot(cumulative_interest_paid, color='red', label='Paid interest')
plt.plot(cumulative_home_equity, color='blue', label='Home equity')
plt.legend()
plt.show()
# Out:
# [0.25241909 0.25484317 0.25727223 0.25970631 0.2621454  0.26458951
#  0.26703866 0.26949286 0.27195211 0.27441643 0.27688583 0.27936031
#  0.28183989 0.28432457 0.28681437 0.28930929 0.29180934 0.29431457
#  0.29682494 0.29934049 0.3018612  0.30438711 0.30691823 0.30945457
#  0.31199614 0.31454294 0.31709497 0.31965226 0.32221483 0.32478269
#  0.32735583 0.32993426 0.332518   0.33510706 0.33770146 0.3403012
#  0.34290629 0.34551674 0.3481326  0.35075383 0.35338046 0.35601249
#  0.35864994 0.36129283 0.36394117 0.36659497 0.36925423 0.37191897
#  0.3745892  0.37726491 0.37994614 0.38263291 0.3853252  0.38802303
#  0.39072643 0.3934354  0.39614994 0.39887009 0.40159583 0.40432717
#  0.40706414 0.40980677 0.41255503 0.41530897 0.41806857 0.42083386
#  0.42360483 0.42638151 0.42916391 0.43195206 0.43474594 0.43754557
#  0.44035097 0.44316217 0.44597914 0.44880191 0.45163051 0.45446494
#  0.4573052  0.46015131 0.46300329 0.46586114 0.46872489 0.47159451
#  0.47447006 0.47735151 0.48023891 0.48313226 0.48603157 0.48893686
#  0.49184811 0.49476537 0.49768863 0.50061791 0.50355323 0.5064946
#  0.50944203 0.51239554 0.51535514 0.51832083 0.52129263 0.52427054
#  0.5272546  0.5302448  0.53324114 0.53624366 0.53925237 0.54226729
#  0.5452884  0.54831574 0.55134931 0.55438914 0.55743523 0.5604876
#  0.56354626 0.5666112  0.56968246 0.57276006 0.57584397 0.57893426
#  0.58203091 0.58513394 0.58824337 0.5913592  0.59448143 0.59761009
#  0.6007452  0.60388677 0.60703483 0.61018934 0.61335037 0.61651791
#  0.61969197 0.62287257 0.62605971 0.62925343 0.63245371 0.6356606
#  0.63887409 0.6420942  0.64532094 0.64855434 0.6517944  0.65504111
#  0.65829451 0.66155463 0.66482146 0.66809503 0.67137534 0.6746624
#  0.67795623 0.68125683 0.68456423 0.68787846 0.69119951 0.6945274
#  0.69786214 0.70120377 0.70455229 0.70790769 0.71127    0.71463923
#  0.7180154  0.72139854 0.72478863 0.72818571 0.7315898  0.73500089
#  0.738419   0.74184417 0.74527637 0.74871566 0.75216203 0.75561549
#  0.75907606 0.76254377 0.76601863 0.76950063 0.7729898  0.77648617
#  0.77998974 0.78350054 0.78701857 0.79054383 0.79407634 0.79761614
#  0.80116323 0.80471763 0.80827934 0.8118484  0.8154248  0.81900857
#  0.82259974 0.82619829 0.82980426 0.83341766 0.83703849 0.84066677
#  0.84430254 0.8479458  0.85159657 0.85525486 0.85892069 0.86259406
#  0.866275   0.86996351 0.87365963 0.87736337 0.88107474 0.88479374
#  0.8885204  0.89225474 0.89599677 0.89974651 0.90350397 0.90726917
#  0.91104214 0.91482289 0.9186114  0.92240771 0.92621186 0.93002383
#  0.93384366 0.93767137 0.94150694 0.94535043 0.94920183 0.95306117
#  0.95692846 0.96080371 0.96468694 0.96857817 0.97247743 0.97638471
#  0.98030003 0.98422343 0.98815491 0.99209449 0.99604217 0.999998  ]

# %%
growth_array = np.full([mortgage_payment_periods], 0.0025)


# Calculate the cumulative growth over time
cumulative_growth_forecast = np.cumprod(1 + growth_array)

# Forecast the home value over time
home_value_forecast = home_value * cumulative_growth_forecast

# Forecast the home equity value owned over time
cumulative_home_value_owned = home_value_forecast * cumulative_percent_owned

# Plot the home value vs equity accumulated
plt.plot(home_value_forecast, color='red', label='Home value forecast')
plt.plot(cumulative_home_value_owned, color='blue', label='Cumulative home value')
plt.legend()
plt.show()

# %%
decline_array = np.full([mortgage_payment_periods], -0.0045)

# Cumulative drop in home value over time as a ratio
cumulative_decline_forecast = np.cumprod(1+decline_array)

# Forecast the home value over time
home_value_forecast = home_value * cumulative_decline_forecast

# Find all periods where your mortgage is underwater
underwater = principal_remaining > home_value_forecast
print(pd.value_counts(underwater))

# Plot the home value vs principal remaining
plt.plot(home_value_forecast, color='red', label='Home value')
plt.plot(principal_remaining, color='blue', label='Principal remaining')
plt.legend()
plt.show()
# Out:
# False    240
# Name: count, dtype: int64
